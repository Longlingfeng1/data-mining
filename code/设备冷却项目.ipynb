# %%
import pandas as pd
import numpy as np
import csv
#data = csv.reader(open('/Users/maclc/Desktop/冷却塔数据/CH(冷水机组)/TL6.csv','r'))
data = pd.read_excel('/Users/maclc/Desktop/冷却塔数据/CH(冷水机组)/TL8xlswhole4.xls')
data
#data1 = open('/Users/maclc/Desktop/冷却塔数据/CH(冷水机组)/TL8xls.xls', encoding='utf-8-sig')
#data1
# Out:
#                          时间  故障信息  蒸发器出水温度  蒸发器进水温度    冷凝器进水温度    冷凝器出水温度  \
# 0      ﻿2018-09-07 00:00:00     0     8.08     8.10  19.190001  18.860001
# 1      ﻿2018-09-07 00:01:00     0     8.08     8.10  19.190001  18.860001
# 2      ﻿2018-09-07 00:02:00     0     8.09     8.11  19.200001  18.860001
# 3      ﻿2018-09-07 00:03:00     0     8.10     8.11  19.200001  18.870001
# 4      ﻿2018-09-07 00:04:00     0     8.10     8.11  19.200001  18.870001
# 5      ﻿2018-09-07 00:05:00     0     8.10     8.12  19.200001  18.870001
# 6      ﻿2018-09-07 00:06:00     0     8.11     8.12  19.200001  18.879999
# 7      ﻿2018-09-07 00:07:00     0     8.12     8.13  19.200001  18.879999
# 8      ﻿2018-09-07 00:08:00     0     8.12     8.13  19.209999  18.879999
# 9      ﻿2018-09-07 00:09:00     0     8.12     8.14  19.209999  18.879999
# 10     ﻿2018-09-07 00:10:00     0     8.13     8.14  19.209999  18.889999
# 11     ﻿2018-09-07 00:11:00     0     8.13     8.14  19.209999  18.889999
# ...

# %%
import matplotlib.font_manager as fm
from datetime import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline

zhfont1 = fm.FontProperties(fname='/Users/maclc/Downloads/SimHei.ttf') 

xs = [datetime.strptime(d, '\ufeff%Y-%m-%d %H:%M:%S') for d in data['时间']]

plt.figure(figsize=(40, 15))
plt.title('蒸发器出水温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['蒸发器出水温度'],'o-')
plt.ylabel(u'蒸发器出水温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('蒸发器进水温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['蒸发器进水温度'],'o-')
plt.ylabel(u'蒸发器进水温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('冷凝器进水温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['冷凝器进水温度'],'o-')
plt.ylabel(u'冷凝器进水温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('冷凝器出水温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['冷凝器出水温度'],'o-')
plt.ylabel(u'冷凝器出水温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('蒸发器冷媒压力vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['蒸发器冷媒压力'],'o-')
plt.ylabel(u'蒸发器冷媒压力',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('冷凝器冷媒压力vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['冷凝器冷媒压力'],'o-')
plt.ylabel(u'冷凝器冷媒压力',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('油温vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['油温'],'o-')
plt.ylabel(u'油温',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('油压差vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['油压差'],'o-')
plt.ylabel(u'油压差',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('蒸发器冷媒温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['蒸发器冷媒温度'],'o-')
plt.ylabel(u'蒸发器冷媒温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('冷凝器冷媒温度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['冷凝器冷媒温度'],'o-')
plt.ylabel(u'冷凝器冷媒温度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('启动次数vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['启动次数'],'o-')
plt.ylabel(u'启动次数',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('运行时间vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['运行时间'],'o-')
plt.ylabel(u'运行时间',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('相电流A相vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['相电流A相'],'o-')
plt.ylabel(u'相电流A相',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('相电流B相vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['相电流B相'],'o-')
plt.ylabel(u'相电流B相',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('相电流C相vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['相电流C相'],'o-')
plt.ylabel(u'相电流C相',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('马达线圈温度W1vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['马达线圈温度W1'],'o-')
plt.ylabel(u'马达线圈温度W1',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('马达线圈温度W2vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['马达线圈温度W2'],'o-')
plt.ylabel(u'马达线圈温度W2',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('马达线圈温度W3vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['马达线圈温度W3'],'o-')
plt.ylabel(u'马达线圈温度W3',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('空气湿度vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['空气湿度'],'o-')
plt.ylabel(u'空气湿度',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(40, 15))
plt.title('空气温度(℃)vs时间',fontproperties=zhfont1,fontsize=40)
plt.plot(xs,data['空气温度(℃)'],'o-')
plt.ylabel(u'空气温度(℃)',fontproperties=zhfont1,fontsize=30)
plt.xlabel(u'时间',fontproperties=zhfont1,fontsize=30)
plt.tick_params(labelsize=23)

plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()
